# %% [markdown]
# # <font>2.Interact with the OpenWeatherMap API using the API key to retrieve weather data for a specific location</font>

# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://api.openweathermap.org/data/2.5/forecast?lat=44.34&lon=10.99&appid=a2b1a641fded5bf401fc5f2ca4d23f0c' # <-- This is app id also known as api key, which you have to generate your own, and paste it here

#vurl ='https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid=307d11bca480dd730d99187c926&city_name=London'
response = requests.get(url)
data = response.json()
pretty_json = json.dumps(data,indent=4)
print(pretty_json)
# Out:
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1730862000,
#             "main": {
#                 "temp": 280.2,
#                 "feels_like": 280.2,
#                 "temp_min": 278.52,
#                 "temp_max": 280.2,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 938,
#                 "humidity": 85,
#                 "temp_kf": 1.68
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 88
#             },
#             "wind": {
#                 "speed": 0.93,
#                 "deg": 241,
#                 "gust": 0.93
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 03:00:00"
#         },
#         {
#             "dt": 1730872800,
#             "main": {
#                 "temp": 279.55,
#                 "feels_like": 279.55,
#                 "temp_min": 278.25,
#                 "temp_max": 279.55,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 939,
#                 "humidity": 84,
#                 "temp_kf": 1.3
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 90
#             },
#             "wind": {
#                 "speed": 0.88,
#                 "deg": 243,
#                 "gust": 0.91
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 06:00:00"
#         },
#         {
#             "dt": 1730883600,
#             "main": {
#                 "temp": 281.91,
#                 "feels_like": 281.91,
#                 "temp_min": 281.91,
#                 "temp_max": 282.77,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 941,
#                 "humidity": 74,
#                 "temp_kf": -0.86
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 91
#             },
#             "wind": {
#                 "speed": 1.09,
#                 "deg": 15,
#                 "gust": 1.16
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 09:00:00"
#         },
#         {
#             "dt": 1730894400,
#             "main": {
#                 "temp": 284.75,
#                 "feels_like": 283.58,
#                 "temp_min": 284.75,
#                 "temp_max": 284.75,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 941,
#                 "humidity": 62,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 58
#             },
#             "wind": {
#                 "speed": 1.75,
#                 "deg": 31,
#                 "gust": 1.42
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 12:00:00"
#         },
#         {
#             "dt": 1730905200,
#             "main": {
#                 "temp": 282.95,
#                 "feels_like": 282.65,
#                 "temp_min": 282.95,
#                 "temp_max": 282.95,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 941,
#                 "humidity": 79,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 33
#             },
#             "wind": {
#                 "speed": 1.43,
#                 "deg": 38,
#                 "gust": 1.92
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 15:00:00"
#         },
#         {
#             "dt": 1730916000,
#             "main": {
#                 "temp": 279.26,
#                 "feels_like": 279.26,
#                 "temp_min": 279.26,
#                 "temp_max": 279.26,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 941,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 44
#             },
#             "wind": {
#                 "speed": 0.82,
#                 "deg": 234,
#                 "gust": 1
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 18:00:00"
#         },
#         {
#             "dt": 1730926800,
#             "main": {
#                 "temp": 278.74,
#                 "feels_like": 278.74,
#                 "temp_min": 278.74,
#                 "temp_max": 278.74,
#                 "pressure": 1031,
#                 "sea_level": 1031,
#                 "grnd_level": 942,
#                 "humidity": 89,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 91
#             },
#             "wind": {
#                 "speed": 1.07,
#                 "deg": 241,
#                 "gust": 1.16
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 21:00:00"
#         },
#         {
#             "dt": 1730937600,
#             "main": {
#                 "temp": 278.29,
#                 "feels_like": 278.29,
#                 "temp_min": 278.29,
#                 "temp_max": 278.29,
#                 "pressure": 1031,
#                 "sea_level": 1031,
#                 "grnd_level": 942,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 88
#             },
#             "wind": {
#                 "speed": 1.05,
#                 "deg": 248,
#                 "gust": 1.05
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 00:00:00"
#         },
#         {
#             "dt": 1730948400,
#             "main": {
#                 "temp": 278,
#                 "feels_like": 278,
#                 "temp_min": 278,
#                 "temp_max": 278,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 941,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.97,
#                 "deg": 252,
#                 "gust": 1.01
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 03:00:00"
#         },
#         {
#             "dt": 1730959200,
#             "main": {
#                 "temp": 277.75,
#                 "feels_like": 277.75,
#                 "temp_min": 277.75,
#                 "temp_max": 277.75,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 941,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 0.86,
#                 "deg": 250,
#                 "gust": 0.88
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 06:00:00"
#         },
#         {
#             "dt": 1730970000,
#             "main": {
#                 "temp": 282.05,
#                 "feels_like": 282.05,
#                 "temp_min": 282.05,
#                 "temp_max": 282.05,
#                 "pressure": 1031,
#                 "sea_level": 1031,
#                 "grnd_level": 943,
#                 "humidity": 80,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 1.21,
#                 "deg": 15,
#                 "gust": 1.27
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 09:00:00"
#         },
#         {
#             "dt": 1730980800,
#             "main": {
#                 "temp": 284.15,
#                 "feels_like": 283.19,
#                 "temp_min": 284.15,
#                 "temp_max": 284.15,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 942,
#                 "humidity": 72,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 50
#             },
#             "wind": {
#                 "speed": 1.94,
#                 "deg": 27,
#                 "gust": 1.55
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 12:00:00"
#         },
#         {
#             "dt": 1730991600,
#             "main": {
#                 "temp": 282.63,
#                 "feels_like": 282.63,
#                 "temp_min": 282.63,
#                 "temp_max": 282.63,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 942,
#                 "humidity": 84,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 48
#             },
#             "wind": {
#                 "speed": 1.31,
#                 "deg": 38,
#                 "gust": 1.91
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 15:00:00"
#         },
#         {
#             "dt": 1731002400,
#             "main": {
#                 "temp": 279.44,
#                 "feels_like": 279.44,
#                 "temp_min": 279.44,
#                 "temp_max": 279.44,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 941,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 68
#             },
#             "wind": {
#                 "speed": 0.65,
#                 "deg": 231,
#                 "gust": 0.88
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 18:00:00"
#         },
#         {
#             "dt": 1731013200,
#             "main": {
#                 "temp": 278.78,
#                 "feels_like": 278.78,
#                 "temp_min": 278.78,
#                 "temp_max": 278.78,
#                 "pressure": 1031,
#                 "sea_level": 1031,
#                 "grnd_level": 942,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 25
#             },
#             "wind": {
#                 "speed": 0.98,
#                 "deg": 254,
#                 "gust": 1.09
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 21:00:00"
#         },
#         {
#             "dt": 1731024000,
#             "main": {
#                 "temp": 278.27,
#                 "feels_like": 278.27,
#                 "temp_min": 278.27,
#                 "temp_max": 278.27,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 941,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 24
#             },
#             "wind": {
#                 "speed": 1.05,
#                 "deg": 255,
#                 "gust": 1.18
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 00:00:00"
#         },
#         {
#             "dt": 1731034800,
#             "main": {
#                 "temp": 277.9,
#                 "feels_like": 277.9,
#                 "temp_min": 277.9,
#                 "temp_max": 277.9,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 941,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 68
#             },
#             "wind": {
#                 "speed": 0.89,
#                 "deg": 250,
#                 "gust": 0.98
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 03:00:00"
#         },
#         {
#             "dt": 1731045600,
#             "main": {
#                 "temp": 277.57,
#                 "feels_like": 277.57,
#                 "temp_min": 277.57,
#                 "temp_max": 277.57,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 940,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 48
#             },
#             "wind": {
#                 "speed": 1.14,
#                 "deg": 249,
#                 "gust": 1.11
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 06:00:00"
#         },
#         {
#             "dt": 1731056400,
#             "main": {
#                 "temp": 281.85,
#                 "feels_like": 281.85,
#                 "temp_min": 281.85,
#                 "temp_max": 281.85,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 942,
#                 "humidity": 80,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 7
#             },
#             "wind": {
#                 "speed": 1.22,
#                 "deg": 1,
#                 "gust": 1.48
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-08 09:00:00"
#         },
#         {
#             "dt": 1731067200,
#             "main": {
#                 "temp": 284.09,
#                 "feels_like": 283.07,
#                 "temp_min": 284.09,
#                 "temp_max": 284.09,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 941,
#                 "humidity": 70,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 6
#             },
#             "wind": {
#                 "speed": 1.91,
#                 "deg": 16,
#                 "gust": 1.67
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-08 12:00:00"
#         },
#         {
#             "dt": 1731078000,
#             "main": {
#                 "temp": 282.42,
#                 "feels_like": 282.42,
#                 "temp_min": 282.42,
#                 "temp_max": 282.42,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 940,
#                 "humidity": 82,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 8
#             },
#             "wind": {
#                 "speed": 1.03,
#                 "deg": 24,
#                 "gust": 1.34
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-08 15:00:00"
#         },
#         {
#             "dt": 1731088800,
#             "main": {
#                 "temp": 279.09,
#                 "feels_like": 279.09,
#                 "temp_min": 279.09,
#                 "temp_max": 279.09,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 939,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 11
#             },
#             "wind": {
#                 "speed": 0.94,
#                 "deg": 248,
#                 "gust": 1.04
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 18:00:00"
#         },
#         {
#             "dt": 1731099600,
#             "main": {
#                 "temp": 278.5,
#                 "feels_like": 277.64,
#                 "temp_min": 278.5,
#                 "temp_max": 278.5,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 939,
#                 "humidity": 89,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 53
#             },
#             "wind": {
#                 "speed": 1.39,
#                 "deg": 248,
#                 "gust": 1.36
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 21:00:00"
#         },
#         {
#             "dt": 1731110400,
#             "main": {
#                 "temp": 277.93,
#                 "feels_like": 277.93,
#                 "temp_min": 277.93,
#                 "temp_max": 277.93,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 938,
#                 "humidity": 86,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 52
#             },
#             "wind": {
#                 "speed": 1.15,
#                 "deg": 243,
#                 "gust": 1.2
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 00:00:00"
#         },
#         {
#             "dt": 1731121200,
#             "main": {
#                 "temp": 277.67,
#                 "feels_like": 277.67,
#                 "temp_min": 277.67,
#                 "temp_max": 277.67,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 937,
#                 "humidity": 82,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 89
#             },
#             "wind": {
#                 "speed": 1.28,
#                 "deg": 249,
#                 "gust": 1.21
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 03:00:00"
#         },
#         {
#             "dt": 1731132000,
#             "main": {
#                 "temp": 277.49,
#                 "feels_like": 277.49,
#                 "temp_min": 277.49,
#                 "temp_max": 277.49,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 937,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 91
#             },
#             "wind": {
#                 "speed": 1.18,
#                 "deg": 254,
#                 "gust": 1.25
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 06:00:00"
#         },
#         {
#             "dt": 1731142800,
#             "main": {
#                 "temp": 282.21,
#                 "feels_like": 282.21,
#                 "temp_min": 282.21,
#                 "temp_max": 282.21,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 937,
#                 "humidity": 66,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 74
#             },
#             "wind": {
#                 "speed": 1.29,
#                 "deg": 355,
#                 "gust": 1.84
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-09 09:00:00"
#         },
#         {
#             "dt": 1731153600,
#             "main": {
#                 "temp": 284.09,
#                 "feels_like": 282.75,
#                 "temp_min": 284.09,
#                 "temp_max": 284.09,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "grnd_level": 936,
#                 "humidity": 58,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 37
#             },
#             "wind": {
#                 "speed": 1.95,
#                 "deg": 6,
#                 "gust": 2.43
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-09 12:00:00"
#         },
#         {
#             "dt": 1731164400,
#             "main": {
#                 "temp": 282.02,
#                 "feels_like": 281.51,
#                 "temp_min": 282.02,
#                 "temp_max": 282.02,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "grnd_level": 936,
#                 "humidity": 73,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 10
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 7,
#                 "gust": 1.9
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-09 15:00:00"
#         },
#         {
#             "dt": 1731175200,
#             "main": {
#                 "temp": 278.89,
#                 "feels_like": 278.89,
#                 "temp_min": 278.89,
#                 "temp_max": 278.89,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 936,
#                 "humidity": 80,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 52
#             },
#             "wind": {
#                 "speed": 1.18,
#                 "deg": 259,
#                 "gust": 1.31
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 18:00:00"
#         },
#         {
#             "dt": 1731186000,
#             "main": {
#                 "temp": 278.06,
#                 "feels_like": 278.06,
#                 "temp_min": 278.06,
#                 "temp_max": 278.06,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 936,
#                 "humidity": 73,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 59
#             },
#             "wind": {
#                 "speed": 1.32,
#                 "deg": 240,
#                 "gust": 1.32
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 21:00:00"
#         },
#         {
#             "dt": 1731196800,
#             "main": {
#                 "temp": 277.44,
#                 "feels_like": 277.44,
#                 "temp_min": 277.44,
#                 "temp_max": 277.44,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 935,
#                 "humidity": 70,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 49
#             },
#             "wind": {
#                 "speed": 1.18,
#                 "deg": 246,
#                 "gust": 1.27
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-10 00:00:00"
#         },
#         {
#             "dt": 1731207600,
#             "main": {
#                 "temp": 276.94,
#                 "feels_like": 276.94,
#                 "temp_min": 276.94,
#                 "temp_max": 276.94,
#                 "pressure": 1023,
#                 "sea_level": 1023,
#                 "grnd_level": 935,
#                 "humidity": 70,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 5
#             },
#             "wind": {
#                 "speed": 1.04,
#                 "deg": 245,
#                 "gust": 1.16
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-10 03:00:00"
#         },
#         {
#             "dt": 1731218400,
#             "main": {
#                 "temp": 276.63,
#                 "feels_like": 276.63,
#                 "temp_min": 276.63,
#                 "temp_max": 276.63,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 935,
#                 "humidity": 74,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 3
#             },
#             "wind": {
#                 "speed": 1.28,
#                 "deg": 239,
#                 "gust": 1.25
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-10 06:00:00"
#         },
#         {
#             "dt": 1731229200,
#             "main": {
#                 "temp": 281.39,
#                 "feels_like": 281.39,
#                 "temp_min": 281.39,
#                 "temp_max": 281.39,
#                 "pressure": 1024,
#                 "sea_level": 1024,
#                 "grnd_level": 936,
#                 "humidity": 65,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.16,
#                 "deg": 19,
#                 "gust": 1.65
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-10 09:00:00"
#         },
#         {
#             "dt": 1731240000,
#             "main": {
#                 "temp": 283.05,
#                 "feels_like": 282.19,
#                 "temp_min": 283.05,
#                 "temp_max": 283.05,
#                 "pressure": 1022,
#                 "sea_level": 1022,
#                 "grnd_level": 936,
#                 "humidity": 61,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 2.04,
#                 "deg": 29,
#                 "gust": 2.21
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-10 12:00:00"
#         },
#         {
#             "dt": 1731250800,
#             "main": {
#                 "temp": 281.25,
#                 "feels_like": 280.77,
#                 "temp_min": 281.25,
#                 "temp_max": 281.25,
#                 "pressure": 1022,
#                 "sea_level": 1022,
#                 "grnd_level": 935,
#                 "humidity": 78,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.38,
#                 "deg": 49,
#                 "gust": 2.13
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-10 15:00:00"
#         },
#         {
#             "dt": 1731261600,
#             "main": {
#                 "temp": 277.76,
#                 "feels_like": 277.76,
#                 "temp_min": 277.76,
#                 "temp_max": 277.76,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 936,
#                 "humidity": 89,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 0.71,
#                 "deg": 77,
#                 "gust": 1.65
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-10 18:00:00"
#         },
#         {
#             "dt": 1731272400,
#             "main": {
#                 "temp": 278.66,
#                 "feels_like": 277.28,
#                 "temp_min": 278.66,
#                 "temp_max": 278.66,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 939,
#                 "humidity": 79,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 43
#             },
#             "wind": {
#                 "speed": 1.84,
#                 "deg": 111,
#                 "gust": 6.59
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-10 21:00:00"
#         },
#         {
#             "dt": 1731283200,
#             "main": {
#                 "temp": 277.91,
#                 "feels_like": 276.1,
#                 "temp_min": 277.91,
#                 "temp_max": 277.91,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 939,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 69
#             },
#             "wind": {
#                 "speed": 2.14,
#                 "deg": 8,
#                 "gust": 5.01
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-11 00:00:00"
#         }
#     ],
#     "city": {
#         "id": 3163858,
#         "name": "Zocca",
#         "coord": {
#             "lat": 44.34,
#             "lon": 10.99
#         },
#         "country": "IT",
#         "population": 4593,
#         "timezone": 3600,
#         "sunrise": 1730872811,
#         "sunset": 1730908751
#     }
# }

# %%
date_time = data['list'][0]['dt_txt']
date_time
# Out:
# '2024-11-06 03:00:00'

# %% [markdown]
# # 3.Extract relevant weather attributes such as temperature, humidity, wind speed, and  precipitation from the API response

# %%
data_struct = []
for record in data['list']:
    temp = record['main']['temp']
    humid = record['main']['humidity']
    wind_speed = record['wind']['speed']
    desp =record['weather'][0]['description']
    date_time = record['dt_txt']
    data_struct.append({'Temperature':temp,'Humidity':humid,'Wind Speed':wind_speed,'Weather Description':desp,'Date Time':date_time})

data_df = pd.DataFrame(data_struct)
data_df[['Date','Time']] = data_df['Date Time'].str.split(' ',expand=True)
data_df.head()
# Out:
#    Temperature  Humidity  Wind Speed Weather Description            Date Time  \
# 0       280.20        85        0.93     overcast clouds  2024-11-06 03:00:00
# 1       279.55        84        0.88     overcast clouds  2024-11-06 06:00:00
# 2       281.91        74        1.09     overcast clouds  2024-11-06 09:00:00
# 3       284.75        62        1.75       broken clouds  2024-11-06 12:00:00
# 4       282.95        79        1.43    scattered clouds  2024-11-06 15:00:00
#
#          Date      Time
# 0  2024-11-06  03:00:00
# 1  2024-11-06  06:00:00
# 2  2024-11-06  09:00:00
# 3  2024-11-06  12:00:00
# 4  2024-11-06  15:00:00

# %%
data_df.shape
# Out:
# (40, 7)

# %% [markdown]
# # 4.Clean and preprocess the retrieved data, handling missing values or inconsistent  formats.

# %%
data_df.isnull().sum()
# Out:
# Temperature            0
# Humidity               0
# Wind Speed             0
# Weather Description    0
# Date Time              0
# Date                   0
# Time                   0
# dtype: int64

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Temperature          40 non-null     float64
#  1   Humidity             40 non-null     int64
#  2   Wind Speed           40 non-null     float64
#  3   Weather Description  40 non-null     object
#  4   Date Time            40 non-null     object
#  5   Date                 40 non-null     object
#  6   Time                 40 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.3+ KB

# %% [markdown]
# # 5.Perform data modeling to analyze weather patterns, such as calculating average temperature, maximum/minimum values, or trends over time.

# %%
data_df.describe()
# Out:
#        Temperature  Humidity  Wind Speed
# count    40.000000  40.00000   40.000000
# mean    279.938250  80.35000    1.253250
# std       2.373013   9.97574    0.373537
# min     276.630000  58.00000    0.650000
# 25%     277.925000  73.00000    1.017500
# 50%     278.990000  81.00000    1.180000
# 75%     282.027500  89.25000    1.382500
# max     284.750000  93.00000    2.140000

# %% [markdown]
# # <font>6.Visualize the weather data using appropriate plots, such as line charts, bar plots, or scatter plots, to represent temperature changes, precipitation levels, or wind speed variations.</font>

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10,5))
sns.scatterplot(x=data_df['Date Time'],
                y=data_df['Temperature'],
                hue=data_df['Weather Description'])

plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,5))
plt.plot(data_df['Date Time'],data_df['Temperature'])
plt.xticks(rotation=90);

# %% [markdown]
# # <font>7.Apply data aggregation techniques to summarize weather statistics by specific time periods</font>

# %%
data_df.groupby('Date').agg({'Temperature' : 'mean','Wind Speed':'mean'})
# Out:
#             Temperature  Wind Speed
# Date
# 2024-11-06   281.051429    1.138571
# 2024-11-07   280.136250    1.121250
# 2024-11-08   279.961250    1.196250
# 2024-11-09   279.795000    1.356250
# 2024-11-10   279.140000    1.328750
# 2024-11-11   277.910000    2.140000

# %%
data_df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Weather Description',
#        'Date Time', 'Date', 'Time'],
#       dtype='object')

# %% [markdown]
# # <font>9.Explore and visualize relationships between weather attributes, such as temperature and humidity, using correlation plots or heatmaps.</font>

# %%
sns.heatmap(data_df[['Temperature','Humidity','Wind Speed']].corr(),annot=True,cmap='crest')
# Out:
# <Axes: >
